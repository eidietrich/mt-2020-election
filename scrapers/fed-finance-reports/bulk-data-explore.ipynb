# %%
import requests
import pandas as pd
import os
import zipfile

pd.options.display.max_rows=200
pd.options.display.max_columns=100

# %%
# from https://stackoverflow.com/questions/16694907/download-large-file-in-python-with-requests
def download_file(url, local_path):
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(local_path, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192):
                if chunk: # filter out keep-alive new chunks
                    f.write(chunk)
    print('Downloaded to', local_path)
    if (local_path[-4:] == '.zip'):
        with zipfile.ZipFile(local_path, 'r') as f:
            f.extractall(local_path[:-4])
        print('Unzipped to ' + local_path[:-4])

# %%
"""
FEC bulk data files

https://www.fec.gov/data/browse-data/?tab=bulk-data

Data files of interest:
- Candidate master - cn20.zip - Records for candidates registered w/ FEC or on ballot
- Committee master - one record for each committee registerd w/ FEC (federal PACS, party committess, campaign committes, etc.)
    - Use this for "totals" info
- Contributions by individuals
    - Contributions by INDIVIDUALS to FEDERAL COMMITTEES
- Contributions from COMMITTEES to CANDIDATES & INDEPENDENT EXPENDITURES 
- Operating expenditures

"""

def get_mt_federal_candidates():
    url = 'https://www.fec.gov/files/bulk-downloads/2020/cn20.zip'
    local_path = 'data/candidate-list-20.zip'
    download_file(url, local_path)
    names = ["CAND_ID", "CAND_NAME", "CAND_PTY_AFFILIATION", "CAND_ELECTION_YR", "CAND_OFFICE_ST", "CAND_OFFICE", "CAND_OFFICE_DISTRICT", "CAND_ICI", "CAND_STATUS", "CAND_PCC", "CAND_ST1", "CAND_ST2", "CAND_CITY", "CAND_ST", "CAND_ZIP"]
    df = pd.read_csv(local_path, delimiter="|", header=None, names=names)
    mt_2020 = df[
        (df['CAND_OFFICE_ST'] == 'MT') 
        & (df['CAND_ELECTION_YR'] == 2020)
        & (df['CAND_OFFICE'].isin(['H','S'])) # House or Senate
    ]
    mt_2020.to_json('data/mt-2020-candidates.json', orient='records')
    return mt_2020

def get_campaign_summaries(mt_2020_candidate_ids):
    # JUST for 2019-20 period
    url = 'https://www.fec.gov/files/bulk-downloads/2020/webl20.zip'
    local_path = 'data/candidate-committee-summaries-20.zip'
    download_file(url, local_path)
    names = ["CAND_ID", "CAND_NAME", "CAND_ICI", "PTY_CD", "CAND_PTY_AFFILIATION", "TTL_RECEIPTS", "TRANS_FROM_AUTH", "TTL_DISB", "TRANS_TO_AUTH", "COH_BOP", "COH_COP", "CAND_CONTRIB", "CAND_LOANS", "OTHER_LOANS", "CAND_LOAN_REPAY", "OTHER_LOAN_REPAY", "DEBTS_OWED_BY", "TTL_INDIV_CONTRIB", "CAND_OFFICE_ST", "CAND_OFFICE_DISTRICT", "SPEC_ELECTION", "PRIM_ELECTION", "RUN_ELECTION", "GEN_ELECTION", "GEN_ELECTION_PRECENT", "OTHER_POL_CMTE_CONTRIB", "POL_PTY_CONTRIB", "CVG_END_DT", "INDIV_REFUNDS", "CMTE_REFUNDS"]
    df = pd.read_csv(local_path, delimiter="|", header=None, names=names)
    df = df[df['CAND_ID'].isin(mt_2020_candidate_ids)]
    df.to_json('data/mt-2020-candidate-committee-summaries.json', orient='records')
    return df
    

# mt_2020_candidates = get_mt_federal_candidates()
mt_2020_candidate_committees = list(mt_2020_candidates['CAND_PCC'])
mt_2020_candidate_ids = list(mt_2020_candidates['CAND_ID'])
mt_2020_candidate_summaries = get_campaign_summaries(mt_2020_candidate_ids)
# Out:
# Downloaded to data/candidate-committee-summaries-20.zip
# Unzipped to data/candidate-committee-summaries-20

# %%
mt_2020_candidate_summaries
# Out:
#         CAND_ID              CAND_NAME CAND_ICI  PTY_CD CAND_PTY_AFFILIATION  \
# 618   H0MT00090         WINTER, THOMAS        C       1                  DEM
# 619   H0MT00116         RAINS, MATTHEW        C       1                  DEM
# 620   H8MT01232     WILLIAMS, KATHLEEN        C       1                  DEM
# 621   H0MT00108           DOOLING, JOE        C       2                  REP
# 622   H0MT01098            LAMM, DEBRA        C       2                  REP
# 623   H4MT00050    ROSENDALE, MATT MR.        C       2                  REP
# 624   H4MT01033       STAPLETON, COREY        C       2                  REP
# 625   H8MT01182        GIANFORTE, GREG        I       2                  REP
# 1474  S0MT00090  COLLINS, WILMOT JAMES        C       1                  DEM
# 1475  S0MT00108             MUES, JOHN        C       1                  DEM
# 1476  S0MT00116          BALLARD, JACK        C       1                  DEM
# 1477  S2MT00096         DAINES, STEVEN        I       2                  REP
#
#       TTL_RECEIPTS  TRANS_FROM_AUTH    TTL_DISB  TRANS_TO_AUTH     COH_BOP  \
# 618      197671.00             0.00    84020.79           0.00        0.00
# 619       35972.00             0.00    21424.45           0.00        0.00
# 620      829824.27         35820.26   239171.21       35820.26    36957.25
# 621       14297.57             0.00     5136.13           0.00        0.00
# 622       35312.27             0.00     3063.77           0.00        0.00
# 623      721016.87            97.18   139823.99           0.00    76178.38
# 624      122269.76             0.00    38348.78           0.00        0.00
# 625      359696.49         72825.36   338388.32           0.00    31079.69
# 1474     177488.76             0.00   128874.45           0.00        0.00
# 1475     101394.93             0.00    50200.97           0.00        0.00
# 1476      29955.00             0.00    29809.64           0.00        0.00
# 1477    3850669.72        503269.32  1113805.79           0.00  1450176.34
#
#          COH_COP  CAND_CONTRIB  CAND_LOANS  OTHER_LOANS  CAND_LOAN_REPAY  \
# 618    113650.21       6259.50        0.00          0.0              0.0
# 619     14547.55          0.00        0.00       5000.0              0.0
# 620    627610.31          0.00        0.00          0.0              0.0
# 621      9161.44          0.00        0.00          0.0              0.0
# 622     32248.50       2810.02        0.00          0.0              0.0
# 623    657371.26          0.00        0.00          0.0              0.0
# 624     83920.98          0.00        0.00          0.0              0.0
# 625     52387.86          0.00        0.00          0.0              0.0
# 1474    48614.31          0.00        0.00          0.0              0.0
# 1475    51193.96          0.00    18405.67          0.0              0.0
# 1476      145.36        360.00     3000.00          0.0              0.0
# 1477  4187040.27          0.00        0.00          0.0              0.0
#
#       OTHER_LOAN_REPAY  DEBTS_OWED_BY  TTL_INDIV_CONTRIB CAND_OFFICE_ST  \
# 618                0.0           0.00          185911.50             MT
# 619                0.0       41407.82           30972.00             MT
# 620                0.0           0.00          754799.01             MT
# 621                0.0           0.00           14297.57             MT
# 622                0.0           0.00           32502.25             MT
# 623                0.0      157831.00          618653.39             MT
# 624                0.0           0.00          122269.76             MT
# 625                0.0      500000.00           67430.36             MT
# 1474               0.0           0.00          175449.90             MT
# 1475               0.0       54056.39           82989.26             MT
# 1476               0.0        3000.00           26595.00             MT
# 1477               0.0           0.00         2156506.44             MT
#
#       CAND_OFFICE_DISTRICT  SPEC_ELECTION  PRIM_ELECTION  RUN_ELECTION  \
# 618                      0            NaN            NaN           NaN
# 619                      0            NaN            NaN           NaN
# 620                      0            NaN            NaN           NaN
# 621                      0            NaN            NaN           NaN
# 622                      0            NaN            NaN           NaN
# 623                      0            NaN            NaN           NaN
# 624                      0            NaN            NaN           NaN
# 625                      0            NaN            NaN           NaN
# 1474                     0            NaN            NaN           NaN
# 1475                     0            NaN            NaN           NaN
# 1476                     0            NaN            NaN           NaN
# 1477                     0            NaN            NaN           NaN
#
#       GEN_ELECTION  GEN_ELECTION_PRECENT  OTHER_POL_CMTE_CONTRIB  \
# 618            NaN                   NaN                 5000.00
# 619            NaN                   NaN                    0.00
# 620            NaN                   NaN                11500.00
# 621            NaN                   NaN                    0.00
# 622            NaN                   NaN                    0.00
# 623            NaN                   NaN                32089.23
# 624            NaN                   NaN                    0.00
# 625            NaN                   NaN               131475.00
# 1474           NaN                   NaN                    0.00
# 1475           NaN                   NaN                    0.00
# 1476           NaN                   NaN                    0.00
# 1477           NaN                   NaN              1166189.49
#
#       POL_PTY_CONTRIB  CVG_END_DT  INDIV_REFUNDS  CMTE_REFUNDS
# 618               0.0  09/30/2019           0.00          0.00
# 619               0.0  09/30/2019           0.00          0.00
# 620               0.0  09/30/2019        3661.00          0.00
# 621               0.0  09/30/2019           0.00          0.00
# 622               0.0  09/30/2019           0.00          0.00
# 623               0.0  09/30/2019        2700.00          0.00
# 624               0.0  09/30/2019           0.00          0.00
# 625              50.0  09/30/2019        2162.10      25597.79
# 1474              0.0  09/30/2019        4300.00          0.00
# 1475              0.0  09/30/2019           0.00          0.00
# 1476              0.0  09/30/2019           0.00          0.00
# 1477              0.0  09/30/2019       20372.75       4578.75

# %%
mt_2020_candidates
# Out:
#         CAND_ID                CAND_NAME CAND_PTY_AFFILIATION  \
# 640   H0MT00090           WINTER, THOMAS                  DEM
# 641   H0MT00108             DOOLING, JOE                  REP
# 642   H0MT00116           RAINS, MATTHEW                  DEM
# 643   H0MT01080    JOHNSON, TIMOTHY ALAN                  REP
# 644   H0MT01098              LAMM, DEBRA                  REP
# 1620  H4MT00050      ROSENDALE, MATT MR.                  REP
# 1621  H4MT01033         STAPLETON, COREY                  REP
# 2821  H8MT01182          GIANFORTE, GREG                  REP
# 2822  H8MT01232       WILLIAMS, KATHLEEN                  DEM
# 4873  S0MT00090    COLLINS, WILMOT JAMES                  DEM
# 4874  S0MT00108               MUES, JOHN                  DEM
# 4875  S0MT00116            BALLARD, JACK                  DEM
# 4876  S0MT00124  KNOLES, MICHAEL CHANTRY                  DEM
# 4877  S0MT00132            NEUMANN, CORA                  DEM
# 5011  S2MT00096           DAINES, STEVEN                  REP
#
#       CAND_ELECTION_YR CAND_OFFICE_ST CAND_OFFICE  CAND_OFFICE_DISTRICT  \
# 640               2020             MT           H                   0.0
# 641               2020             MT           H                   0.0
# 642               2020             MT           H                   0.0
# 643               2020             MT           H                   0.0
# 644               2020             MT           H                   0.0
# 1620              2020             MT           H                   0.0
# 1621              2020             MT           H                   0.0
# 2821              2020             MT           H                   0.0
# 2822              2020             MT           H                   0.0
# 4873              2020             MT           S                   0.0
# 4874              2020             MT           S                   0.0
# 4875              2020             MT           S                   0.0
# 4876              2020             MT           S                   0.0
# 4877              2020             MT           S                   0.0
# 5011              2020             MT           S                   0.0
#
#      CAND_ICI CAND_STATUS   CAND_PCC                  CAND_ST1 CAND_ST2  \
# 640         C           C  C00700963             P.O. BOX 8248      NaN
# 641         C           N  C00709923      3855 CEDAR VALLEY RD      NaN
# 642         C           C  C00710509               PO BOX 1710      NaN
# 643         C           N  C00711002               PO BOX 1088      NaN
# 644         C           N  C00718585               PO BOX 1915      NaN
# 1620        C           N  C00548289               PO BOX 4907      NaN
# 1621        C           C  C00709915         2015 EASTRIDGE DR      NaN
# 2821        I           C  C00631945            1320 MANLEY RD      NaN
# 2822        C           C  C00701748                PO BOX 548      NaN
# 4873        C           C  C00706317                PO BOX 458      NaN
# 4874        C           N  C00711978  2047 N LAST CHANCE GULCH     #379
# 4875        C           C  C00714295              PO BOX 80466      NaN
# 4876        C           N  C00720672        2210 REMINGTON WAY  APT 127
# 4877        C           N  C00721019               PO BOX 1597      NaN
# 5011        I           C  C00491357               PO BOX 1598      NaN
#
#         CAND_CITY CAND_ST     CAND_ZIP
# 640      MISSOULA      MT      59807.0
# 641        HELENA      MT      59602.0
# 642   GREAT FALLS      MT      59403.0
# 643     CORVALLIS      MT      59828.0
# 644    LIVINGSTON      MT      59047.0
# 1620       HELENA      MT  596044907.0
# 1621     BILLINGS      MT  591027904.0
# 2821      BOZEMAN      MT  597158779.0
# 2822      BOZEMAN      MT      59771.0
# 4873       HELENA      MT      59624.0
# 4874       HELENA      MT      59601.0
# 4875    BILLILNGS      MT      59108.0
# 4876      BOZEMAN      MT      59718.0
# 4877      BOZEMAN      MT      59715.0
# 5011       HELENA      MT  596241598.0

# %%
def get_campaign_summaries():
    # Summary for current campaigns
    # documentation: https://www.fec.gov/campaign-finance-data/all-candidates-file-description/
    url = 'https://www.fec.gov/files/bulk-downloads/2020/webl20.zip'
    local_path = 'data/current20.zip'
    names = ['CAND_ID', 'CAND_NAME', 'CAND_ICI', 'PTY_CD', 'CAND_PTY_AFFILIATION', 'TTL_RECEIPTS', 'TRANS_FROM_AUTH',
            'TTL_DISB', 'TRANS_TO_AUTH', 'COH_BOP', 'COH_COP', 'CAND_CONTRIB', 'CAND_LOANS', 'OTHER_LOANS', 
             'CAND_LOAN_REPAY', 'OTHER_LOAN_REPAY', 'DEBTS_OWED_BY', 'TTL_INDIV_CONTRIB', 
             'CAND_OFFICE_ST', 'CAND_OFFICE_DISTRICT', 'SPEC_ELECTION', 'PRIM_ELECTION', 'RUN_ELECTION', 'GEN_ELECTION',
             'GEN_ELECTION_PRECENT', 'OTHER_POL_CMTE_CONTRIB', 'POL_PTY_CONTRIB', 'CVG_END_DT', 'INDIV_REFUNDS', 'CMTE_REFUNDS'
            ]
    download_file(url, local_path)
    current = pd.read_csv(local_path, delimiter="|", header=None, names=names)
    current = current[current['CAND_OFFICE_ST'] == 'MT']
    current.drop(labels=['SPEC_ELECTION','PRIM_ELECTION','RUN_ELECTION','GEN_ELECTION','GEN_ELECTION_PRECENT'], axis=1, inplace=True)
    return current

current = get_campaign_summaries()
# Out:
# Written to data/current20.zip

# %%
current
# Out:
#         CAND_ID              CAND_NAME CAND_ICI  PTY_CD CAND_PTY_AFFILIATION  \
# 459   H0MT00090         WINTER, THOMAS        C       1                  DEM
# 460   H8MT01232     WILLIAMS, KATHLEEN        C       1                  DEM
# 461   H4MT00050    ROSENDALE, MATT MR.        C       2                  REP
# 462   H4MT01033       STAPLETON, COREY        C       2                  REP
# 463   H8MT01182        GIANFORTE, GREG        I       2                  REP
# 1098  S0MT00090  COLLINS, WILMOT JAMES        C       1                  DEM
# 1099  S2MT00096         DAINES, STEVEN        I       2                  REP
#
#       TTL_RECEIPTS  TRANS_FROM_AUTH   TTL_DISB  TRANS_TO_AUTH     COH_BOP  \
# 459      133635.00             0.00   29789.93           0.00        0.00
# 460      446342.79         35820.26  133214.35       35820.26    36957.25
# 461      269179.17            97.18   40441.05           0.00    76178.38
# 462      108014.00             0.00      25.00           0.00        0.00
# 463      357457.35         72825.36  322806.70           0.00    31079.69
# 1098      91764.37             0.00   39138.31           0.00        0.00
# 1099    2641188.43        422388.20  581045.41           0.00  1450176.34
#
#          COH_COP  CAND_CONTRIB  CAND_LOANS  OTHER_LOANS  CAND_LOAN_REPAY  \
# 459    103845.07        234.00         0.0          0.0              0.0
# 460    350085.69          0.00         0.0          0.0              0.0
# 461    304916.50          0.00         0.0          0.0              0.0
# 462    107989.00          0.00         0.0          0.0              0.0
# 463     65730.34          0.00         0.0          0.0              0.0
# 1098    52626.06       1064.86         0.0          0.0              0.0
# 1099  3510319.36          0.00         0.0          0.0              0.0
#
#       OTHER_LOAN_REPAY  DEBTS_OWED_BY  TTL_INDIV_CONTRIB CAND_OFFICE_ST  \
# 459                0.0            0.0          128401.00             MT
# 460                0.0            0.0          394967.53             MT
# 461                0.0       157831.0          192418.56             MT
# 462                0.0            0.0          108014.00             MT
# 463                0.0       500000.0           67430.36             MT
# 1098               0.0            0.0           90699.51             MT
# 1099               0.0            0.0         1417549.82             MT
#
#       CAND_OFFICE_DISTRICT  OTHER_POL_CMTE_CONTRIB  POL_PTY_CONTRIB  \
# 459                      0                 5000.00              0.0
# 460                      0                    0.00              0.0
# 461                      0                 6500.00              0.0
# 462                      0                    0.00              0.0
# 463                      0               131475.00             50.0
# 1098                     0                    0.00              0.0
# 1099                     0               794692.49              0.0
#
#       CVG_END_DT  INDIV_REFUNDS  CMTE_REFUNDS
# 459   06/30/2019           0.00          0.00
# 460   07/31/2019         186.00          0.00
# 461   06/30/2019        2700.00          0.00
# 462   06/30/2019           0.00          0.00
# 463   06/30/2019        1162.10      25597.79
# 1098  06/30/2019           0.00          0.00
# 1099  06/30/2019       15472.75       1200.00

# %%
def get_individual_contributions():
    # bulk download individual contributions
    url = 'https://www.fec.gov/files/bulk-downloads/2020/indiv20.zip'
    local_path = 'data/individual-contributions-20.zip'
    if not os.path.exists(local_path): download_file(url, local_path) # for testing
    names = ["CMTE_ID", "AMNDT_IND", "RPT_TP", "TRANSACTION_PGI", "IMAGE_NUM", "TRANSACTION_TP", "ENTITY_TP", "NAME", "CITY", "STATE", "ZIP_CODE", "EMPLOYER", "OCCUPATION", "TRANSACTION_DT", "TRANSACTION_AMT", "OTHER_ID", "TRAN_ID", "FILE_NUM", "MEMO_CD", "MEMO_TEXT", "SUB_ID"]
    dtype = {'ZIP_CODE': str, 'TRANSACTION_DT': str}
    individual = pd.read_csv('./data/individual-contributions-20/itcont.txt', dtype=dtype, delimiter="|", header=None, names=names)
    mt_committees = list(mt_2020['CAND_PCC'])
    mt_indv = individual[individual['CMTE_ID'].isin(mt_committees)].copy()
    mt_indv = mt_indv.merge(mt_2020[['CAND_PCC','CAND_NAME']], left_on='CMTE_ID', right_on='CAND_PCC')
    return mt_indv

# THIS IS NOT WORKING AS EXPECTED
def get_committee_contributions():
    # bulk download committee contributions
    url = 'https://www.fec.gov/files/bulk-downloads/2020/oth20.zip'
    local_path = 'data/committee-contributions-20.zip'
    if not os.path.exists(local_path): download_file(url, local_path) # for testing
    names = ["CMTE_ID", "AMNDT_IND", "RPT_TP", "TRANSACTION_PGI", "IMAGE_NUM", "TRANSACTION_TP", "ENTITY_TP", "NAME", "CITY", "STATE", "ZIP_CODE", "EMPLOYER", "OCCUPATION", "TRANSACTION_DT", "TRANSACTION_AMT", "OTHER_ID", "CAND_ID", "TRAN_ID", "FILE_NUM", "MEMO_CD", "MEMO_TEXT", "SUB_ID"]
    dtype = {'ZIP_CODE': str, 'TRANSACTION_DT': str}
    donations = pd.read_csv('data/committee-contributions-20/itoth.txt', dtype=dtype, delimiter="|", header=None, names=names)
#     return donations
    # filter to dontations received by MT Candidate committees
    mt_committees = list(mt_2020['CAND_PCC'])
    mt_comm = donations[donations['CMTE_ID'].isin(mt_committees)].copy()
    mt_comm = mt_comm.merge(mt_2020[['CAND_PCC','CAND_NAME']], left_on='CMTE_ID', right_on='CAND_PCC')
    return mt_comm

# %%
itemized = get_individual_contributions()

# %%
itemized.head()
# Out:
#      CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI           IMAGE_NUM  \
# 0  C00491357         N     Q1               P  201904159146338053
# 1  C00491357         N     Q1               P  201904159146338052
# 2  C00491357         N     Q1               P  201904159146338052
# 3  C00491357         N     Q1               G  201904159146338052
# 4  C00491357         N     Q1               P  201904159146337910
#
#   TRANSACTION_TP ENTITY_TP               NAME      CITY STATE   ZIP_CODE  \
# 0             15       IND  INDRELAND, ILEANA   BOZEMAN    MT  597154795
# 1             15       IND    WALLING, GLADYS  WINIFRED    MT  594890055
# 2             15       IND  MURPHY, RICHARD B   FAIRFAX    VA  220370001
# 3             15       IND      THOMA, CARL D   CHICAGO    IL  606112190
# 4             15       IND       BILLION, JOE   BOZEMAN    MT  597188706
#
#                    EMPLOYER          OCCUPATION TRANSACTION_DT  \
# 0             DELANEY & CO.  REAL ESTATE BROKER       03312019
# 1                      NONE             RETIRED       03252019
# 2  R.B. MURPHY & ASSOCIATES           PRESIDENT       03112019
# 3               THOMA BRAVO           EXECUTIVE       03232019
# 4        BILLION AUTO SALES               OWNER       02062019
#
#   TRANSACTION_AMT OTHER_ID               TRAN_ID FILE_NUM MEMO_CD MEMO_TEXT  \
# 0            2800      NaN  ADFC49698138941DB88D  1326203     NaN       NaN
# 1             100      NaN  A015D0AF2A3AF4AE39C0  1326203     NaN       NaN
# 2            1000      NaN  A3A70E45FF2634DEE8D6  1326203     NaN       NaN
# 3            2800      NaN  A589356CD6DA743B498E  1326203     NaN       NaN
# 4            2700      NaN  ADE03926611B7443C882  1326203     NaN       NaN
#
#                 SUB_ID   CAND_PCC       CAND_NAME
# 0  4041820191646716331  C00491357  DAINES, STEVEN
# 1  4041820191646716325  C00491357  DAINES, STEVEN
# 2  4041820191646716327  C00491357  DAINES, STEVEN
# 3  4041820191646716329  C00491357  DAINES, STEVEN
# 4  4041820191646715477  C00491357  DAINES, STEVEN

# %%
itemized.groupby(['CMTE_ID', 'CAND_NAME']).agg({'CMTE_ID': 'count', 'TRANSACTION_AMT': sum, 'RPT_TP': 'unique'})
# Out:
#                                  CMTE_ID  TRANSACTION_AMT    RPT_TP
# CMTE_ID   CAND_NAME
# C00491357 DAINES, STEVEN            1079          1224141  [Q1, Q2]
# C00548289 ROSENDALE, MATT MR.        117           192234  [Q1, Q2]
# C00631945 GIANFORTE, GREG             75            50620  [Q1, Q2]
# C00700963 WINTER, THOMAS             133           105669      [Q2]
# C00701748 WILLIAMS, KATHLEEN         430           259505      [Q2]
# C00706317 COLLINS, WILMOT JAMES       98            50685      [Q2]
# C00709915 STAPLETON, COREY            58           105910      [Q2]
# C00710509 RAINS, MATTHEW              36            21925      [Q3]
# C00714295 BALLARD, JACK               44            21440      [Q3]

# %%
# individual = get_individual_ccontributions()
committee = get_committee_contributions()

# %%
committee.head()
# Out:
#      CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI           IMAGE_NUM  \
# 0  C00491357         N     Q1               G  201904159146338218
# 1  C00491357         N     Q1               P  201904159146338130
# 2  C00491357         N     Q1               P  201904159146338130
# 3  C00491357         N     Q1               P  201904159146338130
# 4  C00491357         N     Q1               P  201904159146338131
#
#   TRANSACTION_TP ENTITY_TP                                 NAME        CITY  \
# 0            22Z       PAC       CLOUD PEAK ENERGY EMPLOYEE PAC  BROOMFIELD
# 1            18G       COM                 SENATE FIREWALL 2020  ALEXANDRIA
# 2            18J       PAC                          KBR INC PAC     HOUSTON
# 3            18J       COM  ENTERPRISE PRODUCTS PARTNERS LP PAC     HOUSTON
# 4            15J       IND                    VALACH, KENNETH J     HOUSTON
#
#   STATE   ZIP_CODE                   EMPLOYER OCCUPATION TRANSACTION_DT  \
# 0    CO  800218068                        NaN        NaN       03312019
# 1    VA  223141535                        NaN        NaN       03312019
# 2    TX  770027900                        NaN        NaN       03302019
# 3    TX  770025227                        NaN        NaN       03302019
# 4    TX  770243914  TRAMMELL CROW RESIDENTIAL        CEO       03142019
#
#    TRANSACTION_AMT   OTHER_ID               CAND_ID  TRAN_ID FILE_NUM MEMO_CD  \
# 0              200  C00485003  BCF5A71D6683B48FFB32  1326203      NaN     NaN
# 1            51155  C00696567  AA4B0849ECD594DA9BCB  1326203      NaN     NaN
# 2             1000  C00431114  A597B2C3FC2B14A96B62  1326203        X     NaN
# 3              952  C00496752  A9D869F241E3346F5A99  1326203        X     NaN
# 4              933        NaN  A327AC03E044F4B1A922  1326203        X     NaN
#
#              MEMO_TEXT  SUB_ID   CAND_PCC       CAND_NAME
# 0  4041820191646710149     NaN  C00491357  DAINES, STEVEN
# 1  4041820191646716789     NaN  C00491357  DAINES, STEVEN
# 2  4041820191646716791     NaN  C00491357  DAINES, STEVEN
# 3  4041820191646716793     NaN  C00491357  DAINES, STEVEN
# 4  4041820191646716795     NaN  C00491357  DAINES, STEVEN

# %%
individual.groupby(['CMTE_ID', 'CAND_NAME']).agg({'CMTE_ID': 'count', 'TRANSACTION_AMT': sum, 'RPT_TP': 'unique'})
# THIS IS MISSING Q3 for most candidates?
# Out:
#                                  CMTE_ID  TRANSACTION_AMT    RPT_TP
# CMTE_ID   CAND_NAME
# C00491357 DAINES, STEVEN            1079          1224141  [Q1, Q2]
# C00548289 ROSENDALE, MATT MR.        117           192234  [Q1, Q2]
# C00631945 GIANFORTE, GREG             75            50620  [Q1, Q2]
# C00700963 WINTER, THOMAS             133           105669      [Q2]
# C00701748 WILLIAMS, KATHLEEN         430           259505      [Q2]
# C00706317 COLLINS, WILMOT JAMES       98            50685      [Q2]
# C00709915 STAPLETON, COREY            58           105910      [Q2]
# C00710509 RAINS, MATTHEW              36            21925      [Q3]
# C00714295 BALLARD, JACK               44            21440      [Q3]

# %%
committee.groupby(['CMTE_ID', 'CAND_NAME']).agg({'CMTE_ID': 'count', 'TRANSACTION_AMT': sum, 'RPT_TP': 'unique'})
# Out:
#                                CMTE_ID  TRANSACTION_AMT    RPT_TP
# CMTE_ID   CAND_NAME
# C00491357 DAINES, STEVEN           233           853358  [Q1, Q2]
# C00548289 ROSENDALE, MATT MR.        2             5097  [Q1, Q2]
# C00631945 GIANFORTE, GREG           63           199111  [Q1, Q2]
# C00701748 WILLIAMS, KATHLEEN         4            36070      [Q2]
# C00710509 RAINS, MATTHEW             1             5000      [Q3]
# C00714295 BALLARD, JACK              1             3000      [Q3]

# %%
donations[donations['CMTE_ID'].isin(mt_committees)]
# Out:
#          CMTE_ID AMNDT_IND RPT_TP TRANSACTION_PGI           IMAGE_NUM  \
# 17938  C00631945         N     Q1               G  201904139146114612
# 17939  C00631945         N     Q1               P  201904139146114612
# 22260  C00631945         N     Q2               P  201907159150857153
#
#       TRANSACTION_TP ENTITY_TP                      NAME       CITY STATE  \
# 17938            24K       CCM  STEVE DAINES FOR MONTANA     HELENA    MT
# 17939            24K       CCM  STEVE DAINES FOR MONTANA     HELENA    MT
# 22260            24K       COM       BISHOP FOR CONGRESS  CHARLOTTE    NC
#
#         ZIP_CODE EMPLOYER OCCUPATION TRANSACTION_DT  TRANSACTION_AMT  \
# 17938  596241598      NaN        NaN       03312019             2000
# 17939  596241598      NaN        NaN       03312019             2000
# 22260  282113272      NaN        NaN       06202019             1000
#
#         OTHER_ID    CAND_ID               TRAN_ID  FILE_NUM MEMO_CD MEMO_TEXT  \
# 17938  C00491357        NaN  BB3E1539F8AFD44D6A29   1324575     NaN       NaN
# 17939  C00491357        NaN  B1CB97049813B45E6B49   1324575     NaN       NaN
# 22260  C00699660  H0NC09187  B615F16B1829D40A89A1   1340322     NaN       NaN
#
#                     SUB_ID
# 17938  4041320191646278988
# 17939  4041320191646278990
# 22260  4072520191661173673

# %%
mt_2020[['CAND_PCC','CAND_NAME']]
# Out:
#        CAND_PCC                CAND_NAME
# 635   C00700963           WINTER, THOMAS
# 636   C00709923             DOOLING, JOE
# 637   C00710509           RAINS, MATTHEW
# 638   C00711002    JOHNSON, TIMOTHY ALAN
# 639   C00718585              LAMM, DEBRA
# 1613  C00548289      ROSENDALE, MATT MR.
# 1614  C00709915         STAPLETON, COREY
# 2814  C00631945          GIANFORTE, GREG
# 2815  C00701748       WILLIAMS, KATHLEEN
# 4866  C00706317    COLLINS, WILMOT JAMES
# 4867  C00711978               MUES, JOHN
# 4868  C00714295            BALLARD, JACK
# 4869  C00720672  KNOLES, MICHAEL CHANTRY
# 4870  C00721019            NEUMANN, CORA
# 5004  C00491357           DAINES, STEVEN

# %%
donations[donations['CMTE_ID'] == 'C00711002']
# Out:
# Empty DataFrame
# Columns: [CMTE_ID, AMNDT_IND, RPT_TP, TRANSACTION_PGI, IMAGE_NUM, TRANSACTION_TP, ENTITY_TP, NAME, CITY, STATE, ZIP_CODE, EMPLOYER, OCCUPATION, TRANSACTION_DT, TRANSACTION_AMT, OTHER_ID, CAND_ID, TRAN_ID, FILE_NUM, MEMO_CD, MEMO_TEXT, SUB_ID]
# Index: []

# %%
names = ["CMTE_ID", "AMNDT_IND", "RPT_TP", "TRANSACTION_PGI", "IMAGE_NUM", "TRANSACTION_TP", "ENTITY_TP", "NAME", "CITY", "STATE", "ZIP_CODE", "EMPLOYER", "OCCUPATION", "TRANSACTION_DT", "TRANSACTION_AMT", "OTHER_ID", "TRAN_ID", "FILE_NUM", "MEMO_CD", "MEMO_TEXT", "SUB_ID"]
dtype = {'ZIP_CODE': str, 'TRANSACTION_DT': str}
individual = pd.read_csv('./data/individual-contributions-20/itcont.txt', dtype=dtype, delimiter="|", header=None, names=names)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (3,11,12,14,16,17,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# individual[individual['CMTE_ID'] == 'C00700963']

# %%
mt_committees = list(mt_2020['CAND_PCC'])
mt_indv = individual[individual['CMTE_ID'].isin(mt_committees)].copy()
mt_indv = mt_indv.merge(mt_2020[['CAND_PCC','CAND_NAME']], left_on='CMTE_ID', right_on='CAND_PCC')

# cleaning
mt_indv['ZIP_CODE'] = mt_indv['ZIP_CODE'].str.slice(0,5)

use_cols = [
    'CAND_NAME','CAND_PCC','CMTE_ID','RPT_TP','TRANSACTION_PGI', 'ENTITY_TP',
    'NAME','CITY','STATE','ZIP_CODE','EMPLOYER','OCCUPATION','TRANSACTION_DT','TRANSACTION_AMT',
    'OTHER_ID','FILE_NUM','MEMO_CD','MEMO_TEXT','SUB_ID'
]
mt_indv = mt_indv[use_cols]

mt_indv.head()
# Out:
#         CAND_NAME   CAND_PCC    CMTE_ID RPT_TP TRANSACTION_PGI ENTITY_TP  \
# 0  DAINES, STEVEN  C00491357  C00491357     Q1               P       IND
# 1  DAINES, STEVEN  C00491357  C00491357     Q1               P       IND
# 2  DAINES, STEVEN  C00491357  C00491357     Q1               P       IND
# 3  DAINES, STEVEN  C00491357  C00491357     Q1               G       IND
# 4  DAINES, STEVEN  C00491357  C00491357     Q1               P       IND
#
#                 NAME      CITY STATE ZIP_CODE                  EMPLOYER  \
# 0  INDRELAND, ILEANA   BOZEMAN    MT    59715             DELANEY & CO.
# 1    WALLING, GLADYS  WINIFRED    MT    59489                      NONE
# 2  MURPHY, RICHARD B   FAIRFAX    VA    22037  R.B. MURPHY & ASSOCIATES
# 3      THOMA, CARL D   CHICAGO    IL    60611               THOMA BRAVO
# 4       BILLION, JOE   BOZEMAN    MT    59718        BILLION AUTO SALES
#
#            OCCUPATION TRANSACTION_DT TRANSACTION_AMT OTHER_ID FILE_NUM  \
# 0  REAL ESTATE BROKER        3312019            2800      NaN  1326203
# 1             RETIRED        3252019             100      NaN  1326203
# 2           PRESIDENT        3112019            1000      NaN  1326203
# 3           EXECUTIVE        3232019            2800      NaN  1326203
# 4               OWNER        2062019            2700      NaN  1326203
#
#   MEMO_CD MEMO_TEXT               SUB_ID
# 0     NaN       NaN  4041820191646716331
# 1     NaN       NaN  4041820191646716325
# 2     NaN       NaN  4041820191646716327
# 3     NaN       NaN  4041820191646716329
# 4     NaN       NaN  4041820191646715477

# %%
#TODO: Filter to these columns

#TODO: Remove duplicates for ACTBLUE etc.
#TODO: Check for reallocations, make sure I understand how committee stuff is being handled
#TODO: Look @ Center for Responsive Politics data products

# %%
mt_indv['CAND_NAME'].value_counts()
# Out:
# DAINES, STEVEN           1079
# WILLIAMS, KATHLEEN        430
# WINTER, THOMAS            133
# ROSENDALE, MATT MR.       117
# COLLINS, WILMOT JAMES      98
# GIANFORTE, GREG            75
# STAPLETON, COREY           58
# BALLARD, JACK              44
# RAINS, MATTHEW             36
# Name: CAND_NAME, dtype: int64

# %%
# mt_indv[mt_indv['CAND_NAME'] == 'COLLINS, WILMOT JAMES']

# %%
# # Current campaigns
# # documentation: https://www.fec.gov/campaign-finance-data/all-candidates-file-description/


# url = 'https://www.fec.gov/files/bulk-downloads/2020/weball20.zip'
# local_path = 'data/summary20.zip'
# names = ['CAND_ID', 'CAND_NAME', 'CAND_ICI', 'PTY_CD', 'CAND_PTY_AFFILIATION', 'TTL_RECEIPTS', 'TRANS_FROM_AUTH',
#         'TTL_DISB', 'TRANS_TO_AUTH', 'COH_BOP', 'COH_COP', 'CAND_CONTRIB', 'CAND_LOANS', 'OTHER_LOANS', 
#          'CAND_LOAN_REPAY', 'OTHER_LOAN_REPAY', 'DEBTS_OWED_BY', 'TTL_INDIV_CONTRIB', 
#          'CAND_OFFICE_ST', 'CAND_OFFICE_DISTRICT', 'SPEC_ELECTION', 'PRIM_ELECTION', 'RUN_ELECTION', 'GEN_ELECTION',
#          'GEN_ELECTION_PRECENT', 'OTHER_POL_CMTE_CONTRIB', 'POL_PTY_CONTRIB', 'CVG_END_DT', 'INDIV_REFUNDS', 'CMTE_REFUNDS'
#         ]
# download_file(url, local_path)
# df = pd.read_csv(local_path, delimiter="|", header=None, names=names)

# %%
# df = pd.read_csv(local_path, delimiter="|", header=None, names=names)
# mt = df[
#     (df['CAND_OFFICE_ST'] == 'MT') 
# #         & (df['CAND_ELECTION_YR'] == 2020)
# #         & (df['CAND_OFFICE'].isin(['H','S'])) # House or Senate
# ]
