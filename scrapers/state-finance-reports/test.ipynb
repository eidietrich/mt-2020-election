# %%
import pandas as pd

# %%
from functions import get_candidate_finance_reports_cleaned
from functions import fetch_all_contributions_to_candidate

# %%
candidateId = 16009 # Gianforte

# %%
get_candidate_finance_reports_cleaned(candidateId)
# Out:
# [{'reportId': 46349,
#   'fromDateStr': '10/01/2019',
#   'toDateStr': '12/31/2019',
#   'formTypeCode': 'C5',
#   'formTypeDescr': 'Candidate Campaign Finance Report',
#   'candidateId': 16009,
#   'candidateName': 'Gianforte, Greg ',
#   'officeTitle': 'Governor',
#   'electionYear': '2020'},
#  {'reportId': 45899,
#   'fromDateStr': '07/01/2019',
#   'toDateStr': '09/30/2019',
#   'formTypeCode': 'C5',
#   'formTypeDescr': 'Candidate Campaign Finance Report',
#   'candidateId': 16009,
#   'candidateName': 'Gianforte, Greg ',
#   'officeTitle': 'Governor',
#   'electionYear': '2020'},
#  {'reportId': 45525,
#   'fromDateStr': '06/01/2019',
#   'toDateStr': '06/30/2019',
#   'formTypeCode': 'C5',
#   'formTypeDescr': 'Candidate Campaign Finance Report',
#   'candidateId': 16009,
#   'candidateName': 'Gianforte, Greg ',
#   'officeTitle': 'Governor',
#   'electionYear': '2020'}]

# %%
df = fetch_all_contributions_to_candidate(candidateId)
# Out:
# Found 3 reports for Gianforte, Greg
# Fetched 3644 rows for Gianforte, Greg

# %%
df
# Out:
#             Candidate          Reporting Period   Date Paid Entity Name  \
# 0    Gianforte, Greg   10/01/2019 to 12/31/2019  11/22/2019         NaN
# 1    Gianforte, Greg   10/01/2019 to 12/31/2019  11/08/2019         NaN
# 2    Gianforte, Greg   10/01/2019 to 12/31/2019  11/08/2019         NaN
# 3    Gianforte, Greg   10/01/2019 to 12/31/2019  12/09/2019         NaN
# 4    Gianforte, Greg   10/01/2019 to 12/31/2019  12/09/2019         NaN
# ..                ...                       ...         ...         ...
# 951  Gianforte, Greg   06/01/2019 to 06/30/2019  06/25/2019         NaN
# 952  Gianforte, Greg   06/01/2019 to 06/30/2019  06/11/2019         NaN
# 953  Gianforte, Greg   06/01/2019 to 06/30/2019  06/28/2019   MBWDA PAC
# 954  Gianforte, Greg   06/01/2019 to 06/30/2019  06/30/2019         NaN
# 955  Gianforte, Greg   06/01/2019 to 06/30/2019  06/30/2019         NaN
#
#                           First Name Middle Initial  \
# ...
